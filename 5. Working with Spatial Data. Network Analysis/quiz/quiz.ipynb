# %%
# %matplotlib inline

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from mpl_toolkits.basemap import Basemap
import networkx as nx

# %%
sofia = {"lat": 42.6977, "lng": 23.3219}

m = Basemap(projection = "merc", llcrnrlat = 41, llcrnrlon = 22, urcrnrlat = 44.5, urcrnrlon = 29, resolution = "i")
m.drawcoastlines()
m.drawcountries()

x, y = m(sofia["lng"], sofia["lat"])
m.plot(x, y, "o")
plt.show()
# Out:
# C:\Users\DSPetrov\Anaconda3\lib\site-packages\ipykernel_launcher.py:3: MatplotlibDeprecationWarning:
# The dedent function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use inspect.cleandoc instead.
#   This is separate from the ipykernel package so we can avoid doing imports until
# C:\Users\DSPetrov\Anaconda3\lib\site-packages\ipykernel_launcher.py:5: MatplotlibDeprecationWarning:
# The dedent function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use inspect.cleandoc instead.
#   """

# %%
sofia = {"lat": 42.6977, "lng": 23.3219}

# %%
sofia["lat"]
# Out:
# 42.6977

# %%
g = nx.florentine_families_graph()
nx.draw(g, with_labels = True)

# %%
len(nx.shortest_path(g, "Pazzi", "Peruzzi"))
# Out:
# 6

# %%
centrality = nx.betweenness_centrality(g)

# %%
centrality
# Out:
# {'Acciaiuoli': 0.0,
#  'Medici': 0.521978021978022,
#  'Castellani': 0.05494505494505495,
#  'Peruzzi': 0.02197802197802198,
#  'Strozzi': 0.10256410256410257,
#  'Barbadori': 0.09340659340659341,
#  'Ridolfi': 0.11355311355311355,
#  'Tornabuoni': 0.09157509157509157,
#  'Albizzi': 0.21245421245421245,
#  'Salviati': 0.14285714285714288,
#  'Pazzi': 0.0,
#  'Bischeri': 0.1043956043956044,
#  'Guadagni': 0.2545787545787546,
#  'Ginori': 0.0,
#  'Lamberteschi': 0.0}
